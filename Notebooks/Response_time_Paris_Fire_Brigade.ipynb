# %% [markdown]
# <a href="https://colab.research.google.com/github/AnIsAsPe/Regresion-Robusta-para-estimar-tiempo-de-respuesta-de-un-servicio-de-emergencia/blob/main/Notebooks/Response_time_Paris_Fire_Brigade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cargar bibiliotecas y funciones

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import HuberRegressor
from sklearn import metrics
from sklearn.preprocessing import StandardScaler         # solamente para la comparación da la improtancia entre variables explicativas

from scipy.stats import kurtosis, skew

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def correlacion(dataframe, grafica=True, matrix=True, tamaño =(6, 4)):
    '''Devuelve la matriz de correlación de un dataframe
    y sí grafica=True, muestra un mapa de calor de la matriz de correlación'''
    corr=dataframe.corr()
    if grafica==True:
      fig = plt.figure(figsize = tamaño)
      ax = sns.heatmap(corr,
                       vmin = -1,
                       vmax = 1,
                       center = 0,
                       cmap = "coolwarm",
                       annot = True,
                       fmt=".2f",
                       square = True)
      ax.set_xticklabels(ax.get_xticklabels(),
                         rotation = 45,
                         horizontalalignment ='right')
    if matrix==True:
      return corr

# %%
def describe_datos(df):
  unicos =[]
  for col in df:
    unicos.append(df[col].unique())
  unicos = pd.Series(unicos, index=df.columns)
  descripcion = pd.concat([df.dtypes, df.isna().sum(),df.nunique(),unicos], axis=1)
  descripcion.columns = ['dtypes', 'null','nunique','unique' ]
  return(descripcion)

# %% [markdown]
# # Lectura datos y selección de características

# %% [markdown]
# __Cargar etiquetas__

# %%
# Variables respuesta
Ys = pd.read_csv('drive/My Drive/Datos/ParisFireBrigade/y_train.csv',
                     index_col=[0], sep=',',)
print(Ys.shape)
Ys.head(2)
# Out:
# (219337, 3)
#                              delta selection-departure  \
# emergency vehicle selection
# 5105452                                             86
# 4720915                                            164
#
#                              delta departure-presentation  \
# emergency vehicle selection
# 5105452                                               324
# 4720915                                               297
#
#                              delta selection-presentation
# emergency vehicle selection
# 5105452                                               410
# 4720915                                               461

# %%
# Se puede verificar si la última columna es la suma de las otras dos
(Ys.iloc[:,0] + Ys.iloc[:,1] == Ys.iloc[:,2]).sum()==len(Ys)
# Out:
# True

# %% [markdown]
# Nos vamos a concentrar en el tiempo desde la salida del vehículo hasta la presentación en el lugar del siniestro

# %%
y = Ys['delta departure-presentation']

# %% [markdown]
# __Cargar características__

# %%
# Conjunto de caracteristicas (X)
X = pd.read_csv('drive/My Drive/Datos/ParisFireBrigade/x_train.csv',
                sep=',', index_col=[0], parse_dates=['selection time'] )
print(X.shape)
X.head(2)
# Out:
# (219337, 25)
#                              intervention  alert reason category  \
# emergency vehicle selection
# 5105452                          13264186                      3
# 4720915                          12663715                      3
#
#                              alert reason  intervention on public roads  \
# emergency vehicle selection
# 5105452                              2162                             0
# 4720915                              2124                             0
#
#                              floor  location of the event  \
# emergency vehicle selection
# 5105452                          0                  148.0
# 4720915                          1                  136.0
#
#                              longitude intervention  latitude intervention  \
# emergency vehicle selection
# 5105452                                    2.284796              48.879669
# 4720915                                    2.247464              48.818191
#
#                              emergency vehicle emergency vehicle type  ...  \
# emergency vehicle selection                                            ...
# 5105452                                   4511              VSAV BSPP  ...
# 4720915                                   4327                    PSE  ...
#
#                              delta status preceding selection-selection  \
# emergency vehicle selection
# 5105452                                                            2027
# 4720915                                                           28233
#
#                             departed from its rescue center  \
# emergency vehicle selection
# 5105452                                                   1
# 4720915                                                   1
#
#                              longitude before departure  \
# emergency vehicle selection
# 5105452                                        2.288053
# 4720915                                        2.268519
#
#                              latitude before departure  \
# emergency vehicle selection
# 5105452                                      48.884698
# 4720915                                      48.823958
#
#                             delta position gps previous departure-departure  \
# emergency vehicle selection
# 5105452                                                                 NaN
# 4720915                                                                 NaN
#
#                                              GPS tracks departure-presentation  \
# emergency vehicle selection
# 5105452                      2.289000,48.885113;2.288861,48.884998;2.288000...
# 4720915                                                                    NaN
#
#                                     GPS tracks datetime departure-presentation  \
# emergency vehicle selection
# 5105452                      2018-07-08 19:04:43;2018-07-08 19:05:55;2018-0...
# 4720915                                                                    NaN
#
#                                                                  OSRM response  \
# emergency vehicle selection
# 5105452                      {"code":"Ok","routes":[{"geometry":"}yjiH}x}L_...
# 4720915                      {"code":"Ok","routes":[{"geometry":"u|~hHy`zL_...
#
#                              OSRM estimated distance  OSRM estimated duration
# emergency vehicle selection
# 5105452                                        952.5                    105.8
# 4720915                                       2238.5                    243.2
#
# [2 rows x 25 columns]

# %%
describe_datos(X)
# Out:
#                                                          dtypes    null  \
# intervention                                              int64       0
# alert reason category                                     int64       0
# alert reason                                              int64       0
# intervention on public roads                              int64       0
# floor                                                     int64       0
# location of the event                                   float64   12710
# longitude intervention                                  float64       0
# latitude intervention                                   float64       0
# emergency vehicle                                         int64       0
# emergency vehicle type                                   object       0
# rescue center                                             int64       0
# selection time                                   datetime64[ns]       0
# date key sélection                                        int64       0
# time key sélection                                        int64       0
# status preceding selection                               object       0
# delta status preceding selection-selection                int64       0
# departed from its rescue center                           int64       0
# longitude before departure                              float64       0
# latitude before departure                               float64       0
# delta position gps previous departure-departure         float64  214434
# GPS tracks departure-presentation                        object  153533
# GPS tracks datetime departure-presentation               object  153533
# OSRM response                                            object       0
# OSRM estimated distance                                 float64       0
# OSRM estimated duration                                 float64       0
#
#                                                  nunique  \
# intervention                                      200894
# alert reason category                                  9
# alert reason                                         126
# intervention on public roads                           2
# floor                                                 45
# location of the event                                210
# longitude intervention                             83484
# latitude intervention                              74503
# emergency vehicle                                    749
# emergency vehicle type                                75
# rescue center                                         94
# selection time                                    219285
# date key sélection                                   335
# time key sélection                                 76273
# status preceding selection                             2
# delta status preceding selection-selection         50175
# departed from its rescue center                        2
# longitude before departure                          3093
# latitude before departure                           2798
# delta position gps previous departure-departure       40
# GPS tracks departure-presentation                  65758
# GPS tracks datetime departure-presentation         65791
# OSRM response                                     126454
# OSRM estimated distance                            48461
# OSRM estimated duration                             8236
#
#                                                                                             unique
# intervention                                     [13264186, 12663715, 13675521, 12695745, 13698...
# alert reason category                                                  [3, 9, 6, 1, 2, 5, 7, 4, 8]
# alert reason                                     [2162, 2124, 2163, 2112, 2711, 2113, 2135, 212...
# intervention on public roads                                                                [0, 1]
# floor                                            [0, 1, 2, 3, 4, 5, -1, 8, 11, 16, 6, 7, 12, -3...
# location of the event                            [148.0, 136.0, 139.0, 104.0, 157.0, 199.0, 140...
# longitude intervention                           [2.284796, 2.247464, 2.258328, 2.393832, 2.458...
# latitude intervention                            [48.879669, 48.818191, 48.836759, 48.776526, 4...
# emergency vehicle                                [4511, 4327, 4509, 5731, 5623, 4319, 4215, 588...
# emergency vehicle type                           [VSAV BSPP, PSE, VLR BSPP, EPAN, EPA BSPP, FPT...
# rescue center                                    [2447, 2464, 2438, 2510, 2478, 2491, 2448, 248...
# selection time                                   [2018-07-08 19:02:43.990000, 2018-01-04 09:02:...
# date key sélection                               [20180708, 20180104, 20181116, 20180115, 20181...
# time key sélection                               [190243, 90259, 101147, 3846, 3426, 222327, 81...
# status preceding selection                                                    [Rentré, Disponible]
# delta status preceding selection-selection       [2027, 28233, 1981, 1842, 2716, 5592, 37282, 5...
# departed from its rescue center                                                             [1, 0]
# longitude before departure                       [2.288053, 2.268519, 2.272944, 2.3889400000000...
# latitude before departure                        [48.884698, 48.82395800000001, 48.850498, 48.7...
# delta position gps previous departure-departure  [nan, 33.0, 34.0, 25.0, 9.0, 37.0, 13.0, 1.0, ...
# GPS tracks departure-presentation                [2.289000,48.885113;2.288861,48.884998;2.28800...
# GPS tracks datetime departure-presentation       [2018-07-08 19:04:43;2018-07-08 19:05:55;2018-...
# OSRM response                                    [{"code":"Ok","routes":[{"geometry":"}yjiH}x}L...
# OSRM estimated distance                          [952.5, 2238.5, 3026.4, 1934.2, 2706.7, 1685.8...
# OSRM estimated duration                          [105.8, 243.2, 295.4, 166.6, 262.6, 187.7, 301...

# %% [markdown]
# La cantidad de intervenciones en los datos no es igual a la cantidad de vehículos, De manera que existen intervenciones que son atendidas por más de un vehiculo de emergencia

# %% [markdown]
# el análisis lo vamos a hacer por vehículo

# %%
#Borrar columnas que no utilizaremos

col_borrar=['intervention',  #identificador de la intervención
            'emergency vehicle',  #id 749 vehículo de emergencia, que están agrupada en 'emergency vehicle type'
            'alert reason', # 126 categorías, que están resumidas en 'alert reason category'

            # Variables geográficas
            'OSRM response', #rutas
            'GPS tracks departure-presentation', #rutas
            'GPS tracks datetime departure-presentation', #rutas
            'longitude intervention', 'latitude intervention', #coordenadas
            'longitude before departure',  #coordenadas
            'latitude before departure',    #coordenadas

            # Redundantes
            'date key sélection', 'time key sélection', # redundantes con 'selection time'

            #variable no relaccionadas con delta departure-presentation
            'status preceding selection',
            'rescue center', # id 94 centros de rescate, estacionamiento de los vehícuos
            'delta status preceding selection-selection',
            'departed from its rescue center',
            'delta position gps previous departure-departure'
            ]
X = X.drop(columns= col_borrar)

X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219337 entries, 5105452 to 4868867
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   alert reason category         219337 non-null  int64
#  1   intervention on public roads  219337 non-null  int64
#  2   floor                         219337 non-null  int64
#  3   location of the event         206627 non-null  float64
#  4   emergency vehicle type        219337 non-null  object
#  5   selection time                219337 non-null  datetime64[ns]
#  6   OSRM estimated distance       219337 non-null  float64
#  7   OSRM estimated duration       219337 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(1)
# memory usage: 15.1+ MB

# %% [markdown]
# __Unir caracteristicas con étiquetas__

# %%
df = pd.concat([X,y], axis=1)
print(df.shape)
df.head(2)
# Out:
# (219337, 9)
#                              alert reason category  \
# emergency vehicle selection
# 5105452                                          3
# 4720915                                          3
#
#                              intervention on public roads  floor  \
# emergency vehicle selection
# 5105452                                                 0      0
# 4720915                                                 0      1
#
#                              location of the event emergency vehicle type  \
# emergency vehicle selection
# 5105452                                      148.0              VSAV BSPP
# 4720915                                      136.0                    PSE
#
#                                      selection time  OSRM estimated distance  \
# emergency vehicle selection
# 5105452                     2018-07-08 19:02:43.990                    952.5
# 4720915                     2018-01-04 09:02:59.470                   2238.5
#
#                              OSRM estimated duration  \
# emergency vehicle selection
# 5105452                                        105.8
# 4720915                                        243.2
#
#                              delta departure-presentation
# emergency vehicle selection
# 5105452                                               324
# 4720915                                               297

# %% [markdown]
# <h2> Idetificación del tipo de variable de cada columna
#
# Comparamos el tipo de cada columna con la documentación de los parámetros de entrada en [la documentación provista por el Challenge](https://paris-fire-brigade.github.io/data-challenge/challenge.html)

# %%
df.dtypes
# Out:
# alert reason category                    int64
# intervention on public roads             int64
# floor                                    int64
# location of the event                  float64
# emergency vehicle type                  object
# selection time                  datetime64[ns]
# OSRM estimated distance                float64
# OSRM estimated duration                float64
# delta departure-presentation             int64
# dtype: object

# %%
categoricas=['alert reason category','location of the event',
             'emergency vehicle type']
df[categoricas] = df[categoricas].astype('object')

df['intervention on public roads']=df['intervention on public roads'].astype('bool')
describe_datos(df)
# Out:
#                                       dtypes   null  nunique  \
# alert reason category                 object      0        9
# intervention on public roads            bool      0        2
# floor                                  int64      0       45
# location of the event                 object  12710      210
# emergency vehicle type                object      0       75
# selection time                datetime64[ns]      0   219285
# OSRM estimated distance              float64      0    48461
# OSRM estimated duration              float64      0     8236
# delta departure-presentation           int64      0     1909
#
#                                                                          unique
# alert reason category                               [3, 9, 6, 1, 2, 5, 7, 4, 8]
# intervention on public roads                                      [False, True]
# floor                         [0, 1, 2, 3, 4, 5, -1, 8, 11, 16, 6, 7, 12, -3...
# location of the event         [148.0, 136.0, 139.0, 104.0, 157.0, 199.0, 140...
# emergency vehicle type        [VSAV BSPP, PSE, VLR BSPP, EPAN, EPA BSPP, FPT...
# selection time                [2018-07-08 19:02:43.990000, 2018-01-04 09:02:...
# OSRM estimated distance       [952.5, 2238.5, 3026.4, 1934.2, 2706.7, 1685.8...
# OSRM estimated duration       [105.8, 243.2, 295.4, 166.6, 262.6, 187.7, 301...
# delta departure-presentation  [324, 297, 365, 160, 523, 419, 452, 404, 411, ...

# %% [markdown]
# # Creación de nuevas variables

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <h3>  Creación de variable Rush Hour
#
# Variable binaria para identificar eventos en horas pico

# %%
df['rush hour'] = 0

df = df.reset_index( )
df = df.set_index('selection time')

#identificar el indice de los registros de eventos en hora pico
pico_am = df.index.indexer_between_time('6:30','9:30')
pico_pm = df.index.indexer_between_time('16:00','19:00')
horas_pico_index= np.concatenate((pico_am, pico_pm))

#identificar los días sabados y domingos
fin_de_semana_filtro = df.index.weekday > 5  #identifica sábados y domingos

# %%
pico_pm
# Out:
# array([    15,     20,     38, ..., 219302, 219314, 219335])

# %%
df.iloc[15]
# Out:
# emergency vehicle selection     4973880
# alert reason category                 3
# intervention on public roads      False
# floor                                 1
# location of the event             139.0
# emergency vehicle type              PSE
# OSRM estimated distance          2305.3
# OSRM estimated duration           302.5
# delta departure-presentation        346
# rush hour                             0
# Name: 2018-05-11 18:56:35.320000, dtype: object

# %%
# cambiar el valor de 'rush hour' a uno cuando sea horas pico
df.iloc[list(horas_pico_index),-1] = 1

#Regresar a 0 el valor para los días sabados y domingos
df['rush hour']= np.where(fin_de_semana_filtro, 0, df['rush hour'])

# %% [markdown]
# <h3> Creación de variable Weekday
#
# Variable binaria para identificar eventos de lunes a viernes

# %%
df['weekday'] = np.where(fin_de_semana_filtro, 0, 1)

# %%
#Regresar emerency vehicle selection como indice
df = df.reset_index()
df = df.set_index('emergency vehicle selection')

# %% [markdown]
# # Manejo de Valores Nulos

# %%
print(df.shape)
describe_datos(df)
# Out:
# (219337, 11)
#                                       dtypes   null  nunique  \
# selection time                datetime64[ns]      0   219285
# alert reason category                 object      0        9
# intervention on public roads            bool      0        2
# floor                                  int64      0       45
# location of the event                 object  12710      210
# emergency vehicle type                object      0       75
# OSRM estimated distance              float64      0    48461
# OSRM estimated duration              float64      0     8236
# delta departure-presentation           int64      0     1909
# rush hour                              int64      0        2
# weekday                                int64      0        2
#
#                                                                          unique
# selection time                [2018-07-08 19:02:43.990000, 2018-01-04 09:02:...
# alert reason category                               [3, 9, 6, 1, 2, 5, 7, 4, 8]
# intervention on public roads                                      [False, True]
# floor                         [0, 1, 2, 3, 4, 5, -1, 8, 11, 16, 6, 7, 12, -3...
# location of the event         [148.0, 136.0, 139.0, 104.0, 157.0, 199.0, 140...
# emergency vehicle type        [VSAV BSPP, PSE, VLR BSPP, EPAN, EPA BSPP, FPT...
# OSRM estimated distance       [952.5, 2238.5, 3026.4, 1934.2, 2706.7, 1685.8...
# OSRM estimated duration       [105.8, 243.2, 295.4, 166.6, 262.6, 187.7, 301...
# delta departure-presentation  [324, 297, 365, 160, 523, 419, 452, 404, 411, ...
# rush hour                                                                [0, 1]
# weekday                                                                  [0, 1]

# %%
df.isna().sum()/len(df)*100  # porcentaje de valores nulos
# Out:
# selection time                  0.000000
# alert reason category           0.000000
# intervention on public roads    0.000000
# floor                           0.000000
# location of the event           5.794736
# emergency vehicle type          0.000000
# OSRM estimated distance         0.000000
# OSRM estimated duration         0.000000
# delta departure-presentation    0.000000
# rush hour                       0.000000
# weekday                         0.000000
# dtype: float64

# %%
df['location of the event'].value_counts(dropna=False)/len(df)*100
# Out:
# location of the event
# 139.0    23.266024
# 136.0    20.242823
# 148.0    14.588054
# NaN       5.794736
# 149.0     4.515882
#            ...
# 324.0     0.000456
# 284.0     0.000456
# 160.0     0.000456
# 293.0     0.000456
# 215.0     0.000456
# Name: count, Length: 211, dtype: float64

# %%
# Porcentaje acumulado
(df['location of the event'].value_counts(dropna=False)/len(df)*100).cumsum().head(13)
# Out:
# location of the event
# 139.0    23.266024
# 136.0    43.508847
# 148.0    58.096901
# NaN      63.891637
# 149.0    68.407519
# 140.0    70.795169
# 107.0    73.015041
# 137.0    75.148288
# 131.0    76.575316
# 104.0    77.800371
# 325.0    78.900505
# 100.0    79.975107
# 259.0    81.046062
# Name: count, dtype: float64

# %% [markdown]
# **Alternativas**
# - Borrar esos renglones,
# - borrar esa variable,
# - imputar valores:
#    - ¿remplazar por ceros?
#    - ¿reemplazar por una medida de tendencia central?
#    - ¿a parir del conocimiento que nos proporcionan las demás variables?

# %% [markdown]
# **¿los valores nulos son aleatorios? ¿se observa algún patrón? ¿borrar los renglónes con valores nulos impacta nuestro modelo?**

# %%
#Distribución de la variable respuesta en registros con y sin valores nulos en "location of the event"
df['nulos'] = np.where(df['location of the event'].isna(),1,0)

sns.boxplot(x = 'nulos' , y = 'delta departure-presentation', data = df,showfliers=False)
# Out:
# <Axes: xlabel='nulos', ylabel='delta departure-presentation'>

# %% [markdown]
# La siguiente celda de código ejemplifica cómo la distribución de la etiqueta sería la misma si los errores fueran aleatorios.
# (Descomenta las líneas y observa las diferencias con los resultados anteriores)

# %%
# muestra = pd.Series(0, index = y.index)
# muestra[y.sample(12710).index]=1
# y_muestra = df.loc[muestra==1, 'delta departure-presentation']
# y_NoMuestra = df.loc[muestra==0, 'delta departure-presentation']
# sns.boxplot(x = muestra , y = df['delta departure-presentation'], showfliers=False)
# plt.show()

# %% [markdown]
# **¿Podemos imputar valores con el conocimiento que tenemos de los demás registros?**

# %%
col_numericas = list(df.select_dtypes(include=['int64', 'float64', 'bool']).columns)
correlacion(df[col_numericas])

# %%
tabla = (pd.crosstab(df['alert reason category'],df['nulos'], normalize = 'columns')*100)

sns.heatmap(tabla,  vmin = 0, vmax = 100, cmap = "coolwarm", annot = True,
            fmt=".1f")
# Out:
# <Axes: xlabel='nulos', ylabel='alert reason category'>

# %%
# Para imputar los valores nulos en 'alert reason category', tomamos la moda que le corresponda segun la categoria que tenga en 'location of the event'
dict_alert_location = df.groupby('alert reason category')['location of the event'].agg(pd.Series.mode).to_dict()
dict_alert_location
# Out:
# {1: 131.0,
#  2: 149.0,
#  3: 139.0,
#  4: 139.0,
#  5: 148.0,
#  6: 148.0,
#  7: 148.0,
#  8: 131.0,
#  9: 139.0}

# %%
# remplazamos los valores nulos en 'location of the event' de acuerdo al valor que presenta

df['location of the event'] = df['location of the event'].fillna( df['alert reason category'].map(dict_alert_location))
df['location of the event'].isna().sum()
# Out:
# 0

# %%
df['location of the event'] = df['location of the event'].astype('int').astype('object')

# %%
# borrar la columna de nulos
df = df.drop('nulos', axis=1)

# %% [markdown]
# # One hot encoding variables categoricas

# %%
df[categoricas].nunique()
# Out:
# alert reason category       9
# location of the event     210
# emergency vehicle type     75
# dtype: int64

# %% [markdown]
# ¿Vale la pena considerar todas las categorias para el one hot encodig?

# %%
df_column = df['alert reason category']
porcentaje = 99

frecuencia = df_column.value_counts()
sum_acumulada = (df_column.value_counts()/len(df)*100).cumsum().round(2)
pareto_df = pd.DataFrame({'Frecuencia':frecuencia,
                          'Porcentje_acumulado':sum_acumulada,
                          'Limite': porcentaje})
pareto_df
# Out:
#                        Frecuencia  Porcentje_acumulado  Limite
# alert reason category
# 3                          176787                80.60      99
# 1                           21270                90.30      99
# 9                            7481                93.71      99
# 2                            5705                96.31      99
# 6                            4814                98.50      99
# 4                            1221                99.06      99
# 7                             901                99.47      99
# 5                             781                99.83      99
# 8                             377               100.00      99

# %%
pareto_df['Categorías importantes'] = np.where(
    (pareto_df['Limite'] <= pareto_df['Porcentje_acumulado']) &
    (pareto_df['Limite'].shift(1) <= pareto_df['Porcentje_acumulado'].shift(1)),
      0, 100)
pareto_df
# Out:
#                        Frecuencia  Porcentje_acumulado  Limite  \
# alert reason category
# 3                          176787                80.60      99
# 1                           21270                90.30      99
# 9                            7481                93.71      99
# 2                            5705                96.31      99
# 6                            4814                98.50      99
# 4                            1221                99.06      99
# 7                             901                99.47      99
# 5                             781                99.83      99
# 8                             377               100.00      99
#
#                        Categorías importantes
# alert reason category
# 3                                         100
# 1                                         100
# 9                                         100
# 2                                         100
# 6                                         100
# 4                                         100
# 7                                           0
# 5                                           0
# 8                                           0

# %%
def categorias_utiles_pareto(df_column, porcentaje):
    # Data Frame con datos necesarios.
    frecuencia = df_column.value_counts()
    sum_acumulada = (df_column.value_counts()/len(df)*100).cumsum()
    pareto_df = pd.DataFrame({'Frecuencia':frecuencia,
                              'Porcentje_acumulado':sum_acumulada,
                              'Limite': porcentaje})

    # Obtención de categorías utiles.
    pareto_df['Categorías importantes'] = np.where(
    (pareto_df['Limite'] <= pareto_df['Porcentje_acumulado']) &             \
    (pareto_df['Limite'].shift(1) <= pareto_df['Porcentje_acumulado'].shift(1)),
      0, 100)
    categorias_utiles = pareto_df[pareto_df['Categorías importantes']==100].index.to_list()

   # Imprimir información util.
    print(f'Categorias: {pareto_df.shape[0]}')
    print(f'Categorias que hacen el {porcentaje}%: {len(categorias_utiles)}')
    print(f'Categorias importantes = {categorias_utiles}')


    # Gráfica de Pareto
    fig, axes = plt.subplots()
    ax1 = pareto_df.plot(use_index=True, y='Frecuencia',  kind='bar',
                         ax=axes, legend=False)
    ax2 = pareto_df.plot(use_index=True, y='Porcentje_acumulado', kind='line',
                         marker='D', ms=1, color="C1", ax=axes,
                         secondary_y=True, legend=False).legend(loc='lower right')
    axes.right_ax.set_ylim(0,105)
    ax3 = pareto_df.plot(use_index=True, y='Limite', color="gray", kind='line',
                         linestyle='dashed', ax=axes, secondary_y=True, legend=False).legend(loc='lower right')
    ax4 = pareto_df.plot(use_index=True, y='Categorías importantes',
                         color="yellow", kind='area', ax=axes,
                         secondary_y=True, alpha=0.1, legend=False).legend(loc='lower right')
    plt.title(f'{df_column.name}')

    return categorias_utiles

cat_location = categorias_utiles_pareto(df['location of the event'], 99)
# Out:
# Categorias: 210
# Categorias que hacen el 99%: 96
# Categorias importantes = [139, 136, 148, 149, 131, 140, 107, 137, 104, 325, 100, 259, 228, 241, 219, 135, 196, 105, 202, 210, 147, 224, 218, 199, 211, 257, 201, 226, 164, 232, 114, 216, 274, 323, 112, 143, 258, 138, 128, 111, 206, 205, 130, 222, 101, 244, 230, 233, 167, 108, 231, 229, 146, 118, 127, 134, 198, 220, 204, 227, 191, 270, 141, 115, 261, 264, 207, 212, 242, 286, 237, 121, 203, 106, 157, 113, 322, 179, 254, 209, 316, 260, 276, 125, 133, 189, 186, 320, 194, 263, 165, 221, 120, 103, 236, 208]

# %%
cat_vehicle = categorias_utiles_pareto(df['emergency vehicle type'], 99)
# Out:
# Categorias: 75
# Categorias que hacen el 99%: 14
# Categorias importantes = ['VSAV BSPP', 'PSE', 'VLR BSPP', 'FPT BSPP', 'AR', 'FA', 'EPA BSPP', 'EPAN', 'CCR BSPP', 'CRF', 'FNPC', 'VID', 'BEAA BSPP', 'EPSA']

# %%
# @title
cat_reason = categorias_utiles_pareto(df['alert reason category'], 99)
# Out:
# Categorias: 9
# Categorias que hacen el 99%: 6
# Categorias importantes = [3, 1, 9, 2, 6, 4]

# %%
describe_datos(df[categoricas])
# Out:
#                         dtypes  null  nunique  \
# alert reason category   object     0        9
# location of the event   object     0      210
# emergency vehicle type  object     0       75
#
#                                                                    unique
# alert reason category                         [3, 9, 6, 1, 2, 5, 7, 4, 8]
# location of the event   [148, 136, 139, 104, 157, 199, 140, 107, 325, ...
# emergency vehicle type  [VSAV BSPP, PSE, VLR BSPP, EPAN, EPA BSPP, FPT...

# %%
df['alert reason category'] = np.where(df['alert reason category'].isin(cat_reason),
                                       df['alert reason category'], np.nan)
df['emergency vehicle type'] = np.where(df['emergency vehicle type'].isin(cat_vehicle),
                                       df['emergency vehicle type'], np.nan)
df['location of the event'] = np.where(df['location of the event'].isin(cat_location),
                                       df['location of the event'], np.nan)

# En la transformación previa de las variables categoricas, podríamos cambiar np.nan por 'other',
# pero de esta manera, la categoria a eliminar en get_dummies sería por default sera np.nan

describe_datos(df[categoricas])
# Out:
#                         dtypes  null  nunique  \
# alert reason category   object  2059        6
# location of the event   object  2189       96
# emergency vehicle type  object  2166       14
#
#                                                                    unique
# alert reason category                             [3, 9, 6, 1, 2, nan, 4]
# location of the event   [148, 136, 139, 104, 157, 199, 140, 107, 325, ...
# emergency vehicle type  [VSAV BSPP, PSE, VLR BSPP, EPAN, EPA BSPP, FPT...

# %%
he = pd.get_dummies(df[categoricas])
print(he.shape)
he.head()
# Out:
# (219337, 116)
#                              alert reason category_1  alert reason category_2  \
# emergency vehicle selection
# 5105452                                        False                    False
# 4720915                                        False                    False
# 5365374                                        False                    False
# 4741586                                        False                    False
# 5381209                                        False                    False
#
#                              alert reason category_3  alert reason category_4  \
# emergency vehicle selection
# 5105452                                         True                    False
# 4720915                                         True                    False
# 5365374                                         True                    False
# 4741586                                         True                    False
# 5381209                                         True                    False
#
#                              alert reason category_6  alert reason category_9  \
# emergency vehicle selection
# 5105452                                        False                    False
# 4720915                                        False                    False
# 5365374                                        False                    False
# 4741586                                        False                    False
# 5381209                                        False                    False
#
#                              location of the event_100  \
# emergency vehicle selection
# 5105452                                          False
# 4720915                                          False
# 5365374                                          False
# 4741586                                          False
# 5381209                                          False
#
#                              location of the event_101  \
# emergency vehicle selection
# 5105452                                          False
# 4720915                                          False
# 5365374                                          False
# 4741586                                          False
# 5381209                                          False
#
#                              location of the event_103  \
# emergency vehicle selection
# 5105452                                          False
# 4720915                                          False
# 5365374                                          False
# 4741586                                          False
# 5381209                                          False
#
#                              location of the event_104  ...  \
# emergency vehicle selection                             ...
# 5105452                                          False  ...
# 4720915                                          False  ...
# 5365374                                          False  ...
# 4741586                                          False  ...
# 5381209                                           True  ...
#
#                              emergency vehicle type_EPA BSPP  \
# emergency vehicle selection
# 5105452                                                False
# 4720915                                                False
# 5365374                                                False
# 4741586                                                False
# 5381209                                                False
#
#                              emergency vehicle type_EPAN  \
# emergency vehicle selection
# 5105452                                            False
# 4720915                                            False
# 5365374                                            False
# 4741586                                            False
# 5381209                                            False
#
#                              emergency vehicle type_EPSA  \
# emergency vehicle selection
# 5105452                                            False
# 4720915                                            False
# 5365374                                            False
# 4741586                                            False
# 5381209                                            False
#
#                              emergency vehicle type_FA  \
# emergency vehicle selection
# 5105452                                          False
# 4720915                                          False
# 5365374                                          False
# 4741586                                          False
# 5381209                                          False
#
#                              emergency vehicle type_FNPC  \
# emergency vehicle selection
# 5105452                                            False
# 4720915                                            False
# 5365374                                            False
# 4741586                                            False
# 5381209                                            False
#
#                              emergency vehicle type_FPT BSPP  \
# emergency vehicle selection
# 5105452                                                False
# 4720915                                                False
# 5365374                                                False
# 4741586                                                False
# 5381209                                                False
#
#                              emergency vehicle type_PSE  \
# emergency vehicle selection
# 5105452                                           False
# 4720915                                            True
# 5365374                                           False
# 4741586                                           False
# 5381209                                           False
#
#                              emergency vehicle type_VID  \
# emergency vehicle selection
# 5105452                                           False
# 4720915                                           False
# 5365374                                           False
# 4741586                                           False
# 5381209                                           False
#
#                              emergency vehicle type_VLR BSPP  \
# emergency vehicle selection
# 5105452                                                False
# 4720915                                                False
# 5365374                                                False
# 4741586                                                False
# 5381209                                                False
#
#                              emergency vehicle type_VSAV BSPP
# emergency vehicle selection
# 5105452                                                  True
# 4720915                                                 False
# 5365374                                                  True
# 4741586                                                  True
# 5381209                                                  True
#
# [5 rows x 116 columns]

# %%
df.columns
# Out:
# Index(['selection time', 'alert reason category',
#        'intervention on public roads', 'floor', 'location of the event',
#        'emergency vehicle type', 'OSRM estimated distance',
#        'OSRM estimated duration', 'delta departure-presentation', 'rush hour',
#        'weekday'],
#       dtype='object')

# %%
df.shape, he.shape
# Out:
# ((219337, 11), (219337, 116))

# %%
df = df.drop(columns=categoricas)
df = pd.concat([df, he], axis=1)
df.shape
# Out:
# (219337, 124)

# %%
#Llevar la etiqueta hasta la ultima posición

df = df[[c for c in df if c != 'delta departure-presentation'] + ['delta departure-presentation']]
print(df.shape)
df.info()
# Out:
# (219337, 124)
# <class 'pandas.core.frame.DataFrame'>
# Index: 219337 entries, 5105452 to 4868867
# Columns: 124 entries, selection time to delta departure-presentation
# dtypes: bool(117), datetime64[ns](1), float64(2), int64(4)
# memory usage: 37.9 MB

# %%
df.columns
# Out:
# Index(['selection time', 'intervention on public roads', 'floor',
#        'OSRM estimated distance', 'OSRM estimated duration', 'rush hour',
#        'weekday', 'alert reason category_1', 'alert reason category_2',
#        'alert reason category_3',
#        ...
#        'emergency vehicle type_EPAN', 'emergency vehicle type_EPSA',
#        'emergency vehicle type_FA', 'emergency vehicle type_FNPC',
#        'emergency vehicle type_FPT BSPP', 'emergency vehicle type_PSE',
#        'emergency vehicle type_VID', 'emergency vehicle type_VLR BSPP',
#        'emergency vehicle type_VSAV BSPP', 'delta departure-presentation'],
#       dtype='object', length=124)

# %%
boleanas=[]
for col in df.columns:
  if df[col].nunique()==2:
    boleanas.append(col)
df[boleanas]=df[boleanas].astype('bool')

# %% [markdown]
# # Exploración de las variables numéricas

# %% [markdown]
# # Eliminar variables no relevantes y redundantes
#
# 1. **No relevantes**: Análisis de correlación de las explicativas(X) con la etiqueta (y)
#
#
# 2. **Redundantes**: Análisis de correlación entre las variables explicativas (X)

# %%
numericas = list(df.select_dtypes(include=['int64', 'float64']).columns)
numericas
# Out:
# ['floor',
#  'OSRM estimated distance',
#  'OSRM estimated duration',
#  'delta departure-presentation']

# %% [markdown]
# <h2> ¿Hay variables que no son relevantes para la predicción de la variable respuesta?

# %%
df[numericas].corr()['delta departure-presentation']
# Out:
# floor                           0.002170
# OSRM estimated distance         0.449922
# OSRM estimated duration         0.446742
# delta departure-presentation    1.000000
# Name: delta departure-presentation, dtype: float64

# %%
fig, (ax1,ax2, ax3) = plt.subplots(1,3, figsize=(18,4))

sns.scatterplot(x='floor', y='delta departure-presentation', data=df, ax=ax1)
sns.scatterplot(x='OSRM estimated distance', y='delta departure-presentation',
                data=df, ax=ax2)
sns.scatterplot(x='OSRM estimated duration', y='delta departure-presentation',
                data=df, ax=ax3)
plt.show()

# %% [markdown]
# <h2> ¿Hay variables redundantes entre las variables explicativas?

# %%
# correlacion de las características numéricas en el conjunto X
corr_matrix = correlacion(df[numericas[:3]])

# %%
#Identificar variables redundantes

# Triangulo superior de la matriz de correlación en números absolutos
celda_sobre_diagonal_ppal = np.triu(np.ones_like(corr_matrix), 1).astype(bool)
triangulo_sup = corr_matrix.where(celda_sobre_diagonal_ppal).abs()


# Encontrar las columnas donde la correlación es 1
redundantes = [column for column in triangulo_sup.columns
          if any(triangulo_sup[column] >= .7)]
redundantes
# Out:
# ['OSRM estimated duration']

# %%
df = df.drop(redundantes, axis=1)

# %%
df.columns
# Out:
# Index(['selection time', 'intervention on public roads', 'floor',
#        'OSRM estimated distance', 'rush hour', 'weekday',
#        'alert reason category_1', 'alert reason category_2',
#        'alert reason category_3', 'alert reason category_4',
#        ...
#        'emergency vehicle type_EPAN', 'emergency vehicle type_EPSA',
#        'emergency vehicle type_FA', 'emergency vehicle type_FNPC',
#        'emergency vehicle type_FPT BSPP', 'emergency vehicle type_PSE',
#        'emergency vehicle type_VID', 'emergency vehicle type_VLR BSPP',
#        'emergency vehicle type_VSAV BSPP', 'delta departure-presentation'],
#       dtype='object', length=123)

# %% [markdown]
# # Exploración de Outliers

# %% [markdown]
# ## Identificar "a ojo" *outliers*

# %%
sns.histplot(df['delta departure-presentation'])
plt.show()

# %%
df['delta departure-presentation'].quantile(.975)
# Out:
# 806.0

# %%
df['outlier'] = 0
filtro_out = df['delta departure-presentation'] > df['delta departure-presentation'].quantile(.975)
df.loc[filtro_out,'outlier'] = 1
# Out:
# <ipython-input-79-bfb88a1278ff>:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['outlier'] = 0

# %%
df['outlier'].value_counts()
# Out:
# outlier
# 0    213857
# 1      5480
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))
for dat, subplot in zip((df, df[-filtro_out], df[filtro_out]), ax.flatten()):
  sns.histplot(x='delta departure-presentation', hue='outlier',
               data=dat, ax=subplot )
plt.show()

# %%
seleccion = ((df['OSRM estimated distance']>20350) & (df['OSRM estimated distance']<20500))
df[seleccion].T
# Out:
# emergency vehicle selection                          4808363  \
# selection time                    2018-02-15 10:58:51.493000
# intervention on public roads                           False
# floor                                                      0
# OSRM estimated distance                              20451.1
# rush hour                                              False
# ...                                                      ...
# emergency vehicle type_VID                             False
# emergency vehicle type_VLR BSPP                        False
# emergency vehicle type_VSAV BSPP                       False
# delta departure-presentation                            1171
# outlier                                                    1
#
# emergency vehicle selection                          5320305  \
# selection time                    2018-10-25 16:32:40.670000
# intervention on public roads                           False
# floor                                                      0
# OSRM estimated distance                              20373.2
# rush hour                                               True
# ...                                                      ...
# emergency vehicle type_VID                             False
# emergency vehicle type_VLR BSPP                         True
# emergency vehicle type_VSAV BSPP                       False
# delta departure-presentation                             609
# outlier                                                    0
#
# emergency vehicle selection                          4832811
# selection time                    2018-02-28 17:44:03.653000
# intervention on public roads                           False
# floor                                                      0
# OSRM estimated distance                              20420.9
# rush hour                                               True
# ...                                                      ...
# emergency vehicle type_VID                             False
# emergency vehicle type_VLR BSPP                         True
# emergency vehicle type_VSAV BSPP                       False
# delta departure-presentation                            1571
# outlier                                                    1
#
# [124 rows x 3 columns]

# %% [markdown]
# Revisa con atención los últimos dos registros mostrados

# %% [markdown]
# # Comparación Regresión lineal, Regresión robusta

# %%
y = df['delta departure-presentation']
X = df.drop(['selection time', 'delta departure-presentation', 'outlier'],
            axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    shuffle=True,
                                                    random_state=261)

# %% [markdown]
# # Guardamos datos preprocesados

# %%
df_preprocesado = pd.concat([X,y], axis=1)
#comprobamos dimensiones
X.shape,    y.shape,   df_preprocesado.shape
# Out:
# ((219337, 121), (219337,), (219337, 122))

# %%
df_preprocesado.to_csv('/content/drive/MyDrive/Datos/ParisFireBrigade/Output/df_selec.csv')

# %%
# ¿Cómo son los conjuntos de entrenamiento y prueba?
print("Conjunto de entrenamiento")
print("X: ", X_train.shape)
print("y: ", y_train.shape)

print("Conjunto de prueba")
print("X: ", X_test.shape)
print("y: ", y_test.shape)
# Out:
# Conjunto de entrenamiento
# X:  (153535, 121)
# y:  (153535,)
# Conjunto de prueba
# X:  (65802, 121)
# y:  (65802,)

# %% [markdown]
# ## Regresión Lineal

# %%
lr = LinearRegression().fit(X_train, y_train)

y_pred = lr.predict(X_test)

error_medio_absoluto = np.mean(np.absolute(y_test - y_pred ))
error_medio_absoluto
# Out:
# 106.9112343525918

# %%
#calculamos los errores
errores = (y_test - y_pred)
len(errores)
# Out:
# 65802

# %% [markdown]
# Tenemos dos tipos de errores:
#
#
#  1) Cuando la prediccción es mas alta que el valor real $ ~~~~\hat{y} > y $
#
#  2) Cuando la predicción es más baja que el valor real $ ~~~~\hat{y} < y $

# %%
#una de las hipotesis de la regresión es que los errores son
#independientes  entre sí, teniendo una distribución normal

print(f'media: {np.mean(errores)}')
print(f'desviación estandar: {np.std(errores)}')
print(f'kurtosis: {kurtosis(errores)}')
print(f'skewness: {skew(errores)}')
# Out:
# media: 1.5768155471138028
# desviación estandar: 201.99137641399906
# kurtosis: 1310.8677866898395
# skewness: 20.409670822280503

# %% [markdown]
# ### Comparación de los errores empirícos con una la distribución normal

# %%
y_test.shape
# Out:
# (65802,)

# %%
# Comparación de la distribución teórica(normal) y empirica de los errores
n = len(y_test)
errores_teoricos = np.random.normal(media, des_est, n)

fig, ax = plt.subplots(1, 2, figsize=(8, 4), sharey='all')
for dat, subplot in zip((errores_teoricos, errores), ax.flatten()):
    sns.histplot(x=dat, ax=subplot, kde=True )

plt.show()

# %% [markdown]
# ### Calculo de [$R^2$](https://docs.google.com/presentation/d/1k0aYwEBzaaAkWjX6jRKAc40nKHi3FROkJwtXCOE22mI/edit#slide=id.ga8926b2cd2_0_14)
#
# $MSE = \cfrac{1}{n}\sum{( y - y_{pred})}^2$
#
#  $R^2 	= 1 -  \cfrac{MSE(modelo)}{MSE(linea~base)}$

# %%
# Error cuadrado medio (MSE) linea base (promedio de las etiquetas)

errores_lb = y_test - y_test.mean()
MSE_base = pow(errores_lb,2).sum()/len(errores_lb)
MSE_base
# Out:
# 52114.94299180111

# %%
#Error cuadrado medio (MSE) modelo
errores = y_test - y_pred

MSE_modelo = pow(errores,2).sum()/len(errores)
MSE_modelo
# Out:
# 40803.00249289147

# %%
R2 = 1 - MSE_modelo/MSE_base #¿cuánto mejora la predicción nuestro modelo?
R2
# Out:
# 0.2170575241862831

# %%
R2 = 1 - MSE_base/MSE_base
R2
# Out:
# 0.0

# %%
def R_cuadrada(val_obs, val_pred):
  errores_lb = val_obs - val_obs.mean()
  errores_m = val_obs - val_pred
  MSE_base = pow(errores_lb,2).sum()/len(errores_lb)
  MSE_modelo = pow(errores,2).sum()/len(errores)
  R2 = 1 - MSE_modelo/MSE_base
  return R2

# %%
R_cuadrada(y_test, y_pred)
# Out:
# 0.2170575241862831

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.2170575241862831

# %% [markdown]
# ## Regresión Robusta

# %%
hr = HuberRegressor(epsilon=1.35,   max_iter=1000,  alpha=0,  warm_start=False,
                    fit_intercept=True, tol=1e-05)
hr = hr.fit(X_train, y_train)
y_pred_hr = hr.predict(X_test)

print(metrics.mean_absolute_error(y_test, y_pred_hr))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_hr))
# Out:
# 104.1078131254273
# MAE: 104.1078131254273

# %%
hr.coef_
# Out:
# array([-8.47943505e-01,  1.33548417e+00,  6.96725651e-02,  1.78924651e+01,
#         8.91920569e-01,  1.98672416e+01,  3.90744236e+00,  3.86984139e+00,
#         8.04863171e+00,  4.62031010e+01,  2.81688412e+01,  7.53331446e+00,
#         2.21782402e+00,  4.64307631e-01,  7.74745033e+00,  4.16183539e+00,
#         4.79027729e-01,  1.00383938e+01,  3.62123638e+00,  3.52397534e+00,
#         4.59672703e+00,  1.38354310e+00,  2.18901625e+00,  1.09297666e+00,
#         5.17492268e-01,  4.52284771e-01,  1.32034836e+00,  9.70450320e-01,
#         2.16488886e+00,  2.34477963e+00,  9.96983291e-01, -3.31446690e+01,
#         2.22218803e-01,  7.18181023e-01,  6.53598978e+00,  1.99713019e+01,
#         1.32876427e+01,  2.06759143e+00,  1.68680274e+01,  1.47236733e+01,
#         1.09296499e+00,  1.37604831e+00,  1.33375333e+00,  5.72015751e+00,
#         2.75478820e+00,  8.88932305e+00, -5.29751117e-01,  2.67959093e+00,
#         3.51055833e-01,  1.60912954e+00, -3.54057804e-01,  1.68150865e-01,
#         3.63107342e-02, -3.98887262e-01,  3.66092316e-01, -1.53803784e+00,
#        -2.41965839e-01, -3.97884238e-01, -1.25444580e-01,  3.06145939e+00,
#         5.58356704e-01, -2.38696693e-01,  1.18459363e+00,  1.65836730e+00,
#         4.66267227e-01, -1.07547900e-01, -3.37652558e-01,  6.57598856e-01,
#         7.72354560e-01,  1.47489794e-01,  1.71687330e+00,  9.47755565e-01,
#         2.50793611e+00, -9.79514586e-02,  1.71269788e-01,  1.21908635e-01,
#        -9.53853171e-01,  9.26062490e-01,  1.66157336e-01, -6.03955524e-01,
#         4.82126180e-01, -4.66345491e-02,  1.64429455e-01, -1.52181545e+00,
#         5.56930206e-01, -2.14909675e-01,  5.64216701e-01,  2.45022317e+00,
#         7.65735595e-01,  5.23605131e-01,  9.27685118e-02,  4.51761823e+00,
#        -3.00850758e-02, -5.40268092e+00,  1.70464775e-01, -3.32765269e-01,
#         8.58088621e-02, -4.20340862e-01, -9.26117017e-01, -1.96484920e+00,
#        -1.99564063e-01,  1.13357625e+00, -3.88634402e-02,  4.91728242e-01,
#        -1.54516274e+00,  1.25965147e+00, -9.18785995e+00, -2.27236918e+01,
#         8.57754825e-01,  1.08019081e+01, -6.67628721e+00,  3.07187951e+00,
#         9.53932350e+00,  1.01529470e+00,  2.18468281e+01, -2.10590050e+00,
#         3.37053796e+01,  4.26942390e+01,  1.31702215e+01,  1.47989016e+01,
#         2.05585540e+01])

# %%
coeficientes_hr = pd.DataFrame({'coef':hr.coef_, 'variable':list(X.columns)})
coeficientes_hr.sort_values('coef').reset_index(drop=True)
# Out:
#           coef                         variable
# 0   -33.144669        location of the event_131
# 1   -22.723692        emergency vehicle type_AR
# 2    -9.187860        location of the event_325
# 3    -6.676287       emergency vehicle type_CRF
# 4    -5.402681        location of the event_259
# ..         ...                              ...
# 116  21.846828        emergency vehicle type_FA
# 117  28.168841          alert reason category_9
# 118  33.705380  emergency vehicle type_FPT BSPP
# 119  42.694239       emergency vehicle type_PSE
# 120  46.203101          alert reason category_6
#
# [121 rows x 2 columns]

# %% [markdown]
# # Estandarizar valores para comparar importancia de variables

# %%
X_estandarizados = X.copy()
columnas = X.columns

scaler = StandardScaler()

X_estandarizados[columnas] = scaler.fit_transform(X[columnas])

# %%
X_estandarizados.describe()
# Out:
#        intervention on public roads         floor  OSRM estimated distance  \
# count                  2.193370e+05  2.193370e+05             2.193370e+05
# mean                   3.602327e-17  6.934155e-17             5.312784e-17
# std                    1.000002e+00  1.000002e+00             1.000002e+00
# min                   -4.143257e-01 -4.479976e+00            -1.405675e+00
# 25%                   -4.143257e-01 -4.806301e-01            -6.389835e-01
# 50%                   -4.143257e-01 -4.806301e-01            -2.333023e-01
# 75%                   -4.143257e-01  3.192391e-01             3.747483e-01
# max                    2.413560e+00  3.951283e+01             2.545460e+01
#
#           rush hour       weekday  alert reason category_1  \
# count  2.193370e+05  2.193370e+05             2.193370e+05
# mean   9.718507e-18 -1.130829e-16             3.508381e-17
# std    1.000002e+00  1.000002e+00             1.000002e+00
# min   -5.286634e-01 -2.518152e+00            -3.277009e-01
# 25%   -5.286634e-01  3.971167e-01            -3.277009e-01
# 50%   -5.286634e-01  3.971167e-01            -3.277009e-01
# 75%   -5.286634e-01  3.971167e-01            -3.277009e-01
# max    1.891563e+00  3.971167e-01             3.051563e+00
#
#        alert reason category_2  alert reason category_3  \
# count             2.193370e+05             2.193370e+05
# mean             -3.242742e-17             1.058669e-16
# std               1.000002e+00             1.000002e+00
# min              -1.634160e-01            -2.038334e+00
# 25%              -1.634160e-01             4.905967e-01
# 50%              -1.634160e-01             4.905967e-01
# 75%              -1.634160e-01             4.905967e-01
# max               6.119350e+00             4.905967e-01
#
#        alert reason category_4  alert reason category_6  ...  \
# count             2.193370e+05             2.193370e+05  ...
# mean             -4.353891e-17            -2.747098e-17  ...
# std               1.000002e+00             1.000002e+00  ...
# min              -7.481937e-02            -1.498015e-01  ...
# 25%              -7.481937e-02            -1.498015e-01  ...
# 50%              -7.481937e-02            -1.498015e-01  ...
# 75%              -7.481937e-02            -1.498015e-01  ...
# max               1.336552e+01             6.675501e+00  ...
#
#        emergency vehicle type_EPA BSPP  emergency vehicle type_EPAN  \
# count                     2.193370e+05                 2.193370e+05
# mean                     -1.295801e-17                -4.431639e-17
# std                       1.000002e+00                 1.000002e+00
# min                      -9.722710e-02                -9.510229e-02
# 25%                      -9.722710e-02                -9.510229e-02
# 50%                      -9.722710e-02                -9.510229e-02
# 75%                      -9.722710e-02                -9.510229e-02
# max                       1.028520e+01                 1.051499e+01
#
#        emergency vehicle type_EPSA  emergency vehicle type_FA  \
# count                 2.193370e+05               2.193370e+05
# mean                 -3.271897e-18               2.944708e-17
# std                   1.000002e+00               1.000002e+00
# min                  -4.668485e-02              -1.079384e-01
# 25%                  -4.668485e-02              -1.079384e-01
# 50%                  -4.668485e-02              -1.079384e-01
# 75%                  -4.668485e-02              -1.079384e-01
# max                   2.142022e+01               9.264543e+00
#
#        emergency vehicle type_FNPC  emergency vehicle type_FPT BSPP  \
# count                 2.193370e+05                     2.193370e+05
# mean                 -4.072055e-17                     1.956659e-17
# std                   1.000002e+00                     1.000002e+00
# min                  -6.285003e-02                    -1.381373e-01
# 25%                  -6.285003e-02                    -1.381373e-01
# 50%                  -6.285003e-02                    -1.381373e-01
# 75%                  -6.285003e-02                    -1.381373e-01
# max                   1.591089e+01                     7.239175e+00
#
#        emergency vehicle type_PSE  emergency vehicle type_VID  \
# count                2.193370e+05                2.193370e+05
# mean                -2.290328e-17               -1.218053e-17
# std                  1.000002e+00                1.000002e+00
# min                 -4.202827e-01               -6.080666e-02
# 25%                 -4.202827e-01               -6.080666e-02
# 50%                 -4.202827e-01               -6.080666e-02
# 75%                 -4.202827e-01               -6.080666e-02
# max                  2.379351e+00                1.644557e+01
#
#        emergency vehicle type_VLR BSPP  emergency vehicle type_VSAV BSPP
# count                     2.193370e+05                      2.193370e+05
# mean                      8.422706e-19                      3.443591e-17
# std                       1.000002e+00                      1.000002e+00
# min                      -1.650993e-01                     -1.634913e+00
# 25%                      -1.650993e-01                     -1.634913e+00
# 50%                      -1.650993e-01                      6.116533e-01
# 75%                      -1.650993e-01                      6.116533e-01
# max                       6.056960e+00                      6.116533e-01
#
# [8 rows x 121 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_estandarizados, y, test_size=0.3,
                                                    shuffle=True, random_state=261)

# %%
hr_st = HuberRegressor( epsilon=1.35,   max_iter=1000,  alpha=0,  warm_start=False,
                    fit_intercept=True, tol=1e-05)
hr_st = hr.fit(X_train, y_train)

# %%
coeficientes_hr_st = pd.Series(hr_st.coef_, index= columnas)

coef_estand = pd.DataFrame(coeficientes_hr_st.sort_values())
coef_estand
# Out:
#                                            0
# alert reason category_3           -18.043541
# alert reason category_1           -12.575435
# location of the event_131         -10.815181
# alert reason category_2            -9.136662
# alert reason category_9            -6.996958
# ...                                      ...
# emergency vehicle type_FPT BSPP    13.017947
# emergency vehicle type_VID         14.883959
# emergency vehicle type_VSAV BSPP   27.605785
# emergency vehicle type_PSE         30.851466
# OSRM estimated distance           112.280016
#
# [121 rows x 1 columns]

# %% [markdown]
# # Referencias
#
# * García, S., Luengo, J., & Herrera, F. (2015). Data Preprocessing in Data Mining. Intelligent Systems Reference Library. doi:10.1007/978-3-319-10247-4
#
#
# * Hawkins, D. M. (1980). Identification of Outliers. Springer Netherlands. https://doi.org/10.1007/978-94-015-3994-4
#
#
# * McDonald, A. (2021, septiembre 8). Using the missingno Python library to Identify and Visualise Missing Data Prior to Machine Learning. Medium. https://towardsdatascience.com/using-the-missingno-python-library-to-identify-and-visualise-missing-data-prior-to-machine-learning-34c8c5b5f009
#
# * Chandrashekar, G., & Sahin, F. (2014). A survey on feature selection methods. Computers & Electrical Engineering, 40(1), 16-28. https://doi.org/10.1016/j.compeleceng.2013.11.024
#
#
# .
